# %%
import pandas as pd

# %%
stats_df = pd.read_csv('player_stats.csv')
stats_df.head()
# Out:
#    playerId                 name posRank  \
# 0   4595348         Malik Nabers      []
# 1   3043078        Derrick Henry      []
# 2   4432708  Marvin Harrison Jr.      []
# 3   4685382      Omarion Hampton      []
# 4   4683062        Xavier Worthy      []
#
#                                        eligibleSlots lineupSlot  \
# 0  ["RB/WR", "WR", "WR/TE", "RB/WR/TE", "OP", "BE...         WR
# 1      ["RB", "RB/WR", "RB/WR/TE", "OP", "BE", "IR"]         RB
# 2  ["RB/WR", "WR", "WR/TE", "RB/WR/TE", "OP", "BE...         WR
# 3  ["Rookie", "RB", "RB/WR", "RB/WR/TE", "OP", "B...         RB
# 4  ["RB/WR", "WR", "WR/TE", "RB/WR/TE", "OP", "BE...   RB/WR/TE
#
#   acquisitionType proTeam  onTeamId position  injuryStatus  injured  \
# 0           DRAFT     NYG       1.0       WR  QUESTIONABLE    False
# 1           DRAFT     BAL       1.0       RB        ACTIVE    False
# 2           DRAFT     ARI       1.0       WR        ACTIVE    False
# 3           DRAFT     LAC       1.0       RB        ACTIVE    False
# 4           DRAFT      KC       1.0       WR        ACTIVE    False
#
#    total_points  avg_points  projected_total_points  projected_avg_points  \
# 0           0.0         0.0                  300.07                 17.65
# 1           0.0         0.0                  280.71                 16.51
# 2           0.0         0.0                  240.02                 14.12
# 3           0.0         0.0                  262.76                 15.46
# 4           0.0         0.0                  239.57                 14.09
#
#    percent_owned  percent_started  \
# 0          99.80            98.07
# 1          99.82            97.98
# 2          96.54            73.94
# 3          94.60            73.53
# 4          96.65            74.63
#
#                                                stats
# 0  {"1": {"projected_points": 19.02, "projected_b...
# 1  {"1": {"projected_points": 16.05, "projected_b...
# 2  {"1": {"projected_points": 13.93, "projected_b...
# 3  {"1": {"projected_points": 14.99, "projected_b...
# 4  {"1": {"projected_points": 17.15, "projected_b...

# %%
sentiment_df = pd.read_csv('player_scraped_info.csv')
sentiment_df.head()
# Out:
#    playerId                 name  \
# 0   4595348         Malik Nabers
# 1   3043078        Derrick Henry
# 2   4432708  Marvin Harrison Jr.
# 3   4685382      Omarion Hampton
# 4   4683062        Xavier Worthy
#
#                                          reddit_text  \
# 0  Title: Giants' Malik Nabers Taken to Locker Ro...
# 1  Title: 2025 League-Winning Draft Strategies - ...
# 2  Title: Is Marvin Harrison Jr. going to be as a...
# 3  Title: What is the earliest you are willing to...
# 4  Title: Chiefs WR Xavier Worthy, who left yeste...
#
#                                    fantasy_pros_text  \
# 0  Malik Nabers exploded in his rookie season as ...
# 1  The BIG DAWG KEEPS EATING! Some players are ju...
# 2  Marvin Harrison Jr. didn't come close to livin...
# 3  Hampton lands with the Bolts after hearing his...
# 4  Add Xavier Worthy to the list of disappointing...
#
#                                            espn_text  \
# 0  ESPN Fantasy Projection\n\n:\n\nNabers is comi...
# 1  News\n\n:\n\n2 days ago\n\nHenry and other key...
# 2  News\n\n:\n\n2 days ago\n\nHarrison (knee) is ...
# 3  ESPN Fantasy Projection\n\n:\n\nHampton was se...
# 4  News\n\n:\n\n7 days ago\n\nCoach Andy Reid rev...
#
#                                            sentiment
# 0  ```json\n{\n    "reddit_summary": "The Reddit ...
# 1  ```json\n{\n    "reddit_summary": "The discuss...
# 2  ```json\n{\n    "reddit_summary": "Reddit disc...
# 3  ```json\n{\n    "reddit_summary": "The Reddit ...
# 4  ```json\n{\n    "reddit_summary": "The discuss...

# %%
import json

malik_sentiment = sentiment_df[sentiment_df['name'] == 'Malik Nabers']['sentiment'].iloc[0]

if malik_sentiment.startswith('```json\n'):
    json_content = malik_sentiment[8:]  # Remove '```json\n'
    if json_content.endswith('\n```'):
        json_content = json_content[:-4]  # Remove '\n```'
    
    final_data = json.loads(json_content)
    
    print("Formatted sentiment data:")
    print(json.dumps(final_data, indent=2))
else:
    print("Unexpected format. Raw data:")
    print(malik_sentiment)
# Out:
# Formatted sentiment data:
# {
#   "reddit_summary": "The Reddit discussion conveys significant concern over Malik Nabers' injury issues and questionable quarterback situation, leading many to recommend avoiding him in drafts. There's a general sentiment of skepticism regarding his value for the upcoming season.",
#   "reddit_sentiment_score": 3,
#   "fantasypros_summary": "FantasyPros presents a much more positive outlook on Malik Nabers, emphasizing his impressive rookie performance and potential as a WR1 despite concerns over quarterback play. They view him as a solid investment for the future.",
#   "fantasypros_sentiment_score": 8,
#   "espn_summary": "ESPN highlights Nabers' successful rookie season, indicating he has the potential to be a top receiver, especially with improved quarterback options for 2025. They project him as a strong WR1 target moving forward.",
#   "espn_sentiment_score": 8,
#   "overall_summary": "The sentiment surrounding Malik Nabers is mixed. While Reddit users express strong concerns due to injuries and quarterback limitations, FantasyPros and ESPN provide a more optimistic analysis based on his exceptional rookie statistics and future prospects. Overall, the outlook is skeptical but hopeful.",
#   "overall_sentiment_score": 5
# }

# %%
final_data['overall_summary']
# Out:
# 'The sentiment surrounding Malik Nabers is mixed. While Reddit users express strong concerns due to injuries and quarterback limitations, FantasyPros and ESPN provide a more optimistic analysis based on his exceptional rookie statistics and future prospects. Overall, the outlook is skeptical but hopeful.'

# %%
json.loads(stats_df.iloc[3].stats)['1']['projected_points']
# Out:
# 14.99

# %%
positions = stats_df.groupby('position').agg({'total_points': 'mean', 'avg_points': 'mean', 'projected_total_points': 'mean', 'percent_owned': 'mean', 'percent_started': 'mean'})
positions
# Out:
#           total_points  avg_points  projected_total_points  percent_owned  \
# position
# D/ST               0.0         0.0              102.646522      46.023913
# K                  0.0         0.0              138.771579      50.957368
# QB                 0.0         0.0              280.340333      55.493333
# RB                 0.0         0.0              185.759180      68.735574
# TE                 0.0         0.0              162.293077      57.311154
# WR                 0.0         0.0              203.006111      71.448889
#
#           percent_started
# position
# D/ST            39.070435
# K               46.824211
# QB              30.736000
# RB              35.013607
# TE              35.816154
# WR              33.803333

# %%
def parse_sentiment_json(sentiment_str):
    try:
        if sentiment_str.startswith('```json\n'):
            json_content = sentiment_str[8:]
            if json_content.endswith('\n```'):
                json_content = json_content[:-4]
            sentiment_data = json.loads(json_content)
            return sentiment_data.get('overall_sentiment_score', 5)
    except:
        return 5

# %%
def evaluate_player(player_name, stats_df, sentiment_df):
    """
    1. Production Score (50% weight)
       - What: Position-relative fantasy performance ranking
       - Calculation: (total_players_at_position - player_rank + 1) / total_players_at_position
       - Data source: projected_total_points compared to same position players
       - Example: RB ranked 3rd out of 50 RBs = (50-3+1)/50 = 0.96
       - Higher = Better projected points vs position peers
    
    2. Reliability Score (30% weight)
       - What: Player dependability based on health + market confidence
       - Components:
         * Injury Status (60%): ACTIVE=1.0, QUESTIONABLE=0.7, DOUBTFUL=0.4, OUT=0.2, IR=0.1
         * Market Confidence (40%): (percent_owned + percent_started) / 200
       - Calculation: (injury_score * 0.6) + (market_confidence * 0.4)
       - Logic: Healthy players + high ownership/start rates = more reliable
       - Higher = Better health + more market trust
    
    3. Sentiment Score (10% weight)
       - What: Expert and community opinion analysis
       - Data source: Scraped sentiment from Reddit/FantasyPros/ESPN (overall_sentiment_score)
       - Calculation: sentiment_value / 10 (converts 1-10 scale to 0-1)
       - Default: 0.5 if no sentiment data available
       - Higher = More positive expert/community sentiment
    
    4. Value Score (10% weight)
       - What: Fantasy efficiency - points per ownership percentage
       - Calculation: projected_total_points / (percent_owned + 1) ranked within position
       - Same percentile formula as production score
       - Logic: High projected points + low ownership = great value
       - Higher = More "bang for your buck" vs position peers
    
    5. Composite Score (Final Rating)
       - Formula: (Production×0.5) + (Reliability×0.3) + (Sentiment×0.1) + (Value×0.1)
       - Range: 0-1 scale where 1.0 = perfect score
       - Interpretation: Overall player quality considering performance, health, opinion, and value
    
    """
    player = stats_df[stats_df['name'] == player_name]
    if player.empty:
        return None
    
    player = player.iloc[0]
    position = player['position']
    position_players = stats_df[stats_df['position'] == position].copy()
    
    position_points = position_players['projected_total_points'].sort_values(ascending=False)
    player_rank = position_points.rank(method='max', ascending=False)[player.name]
    total_at_position = len(position_players)
    production_percentile = (total_at_position - player_rank + 1) / total_at_position
    
    injury_score = {
        'ACTIVE': 1.0,
        'QUESTIONABLE': 0.7,
        'DOUBTFUL': 0.4,
        'OUT': 0.2,
        'IR': 0.1
    }.get(player['injuryStatus'], 0.8)
    
    ownership_confidence = (player['percent_owned'] + player['percent_started']) / 200
    reliability_score = (injury_score * 0.6 + ownership_confidence * 0.4)
    
    player_sentiment_data = sentiment_df[sentiment_df['name'] == player_name]
    if not player_sentiment_data.empty:
        raw_sentiment = parse_sentiment_json(player_sentiment_data.iloc[0]['sentiment'])
        sentiment_score = (raw_sentiment or 5) / 10 
    else:
        sentiment_score = 0.5
    
    position_players.loc[:, 'value_metric'] = position_players['projected_total_points'] / (position_players['percent_owned'] + 1)
    value_rank = position_players['value_metric'].rank(method='max', ascending=False)
    player_value_rank = value_rank.loc[player.name] if player.name in value_rank.index else len(position_players)/2
    value_percentile = (total_at_position - player_value_rank + 1) / total_at_position
    
    composite_score = (
        production_percentile * 0.50 +
        reliability_score * 0.30 +
        sentiment_score * 0.10 +
        value_percentile * 0.10
    )
    
    return {
        'name': player_name,
        'position': position,
        'composite_score': round(composite_score, 3),
        'production_score': round(production_percentile, 3),
        'reliability_score': round(reliability_score, 3),
        'sentiment_score': round(sentiment_score, 3),
        'value_score': round(value_percentile, 3),
        'position_rank': int(player_rank),
    }

# %%
all_results = []
players = stats_df['name'].unique()

for player in players:
    result = evaluate_player(player, stats_df, sentiment_df)
    if result:
        all_results.append(result)

results_df = pd.DataFrame(all_results)

print("=== PLAYER RANKINGS BY POSITION ===\n")

for position in sorted(results_df['position'].unique()):
    position_players = results_df[results_df['position'] == position].sort_values('composite_score', ascending=False)
    
    print(f"{position} RANKINGS:")
    print("-" * 50)
    
    for rank, (_, player) in enumerate(position_players.iterrows(), 1):
        print(f"{rank:2d}. {player['name']:<25} | Score: {player['composite_score']:.3f}")
    
    print()
# Out:
# === PLAYER RANKINGS BY POSITION ===
#
# D/ST RANKINGS:
# --------------------------------------------------
#  1. Texans D/ST               | Score: 0.859
#  2. Steelers D/ST             | Score: 0.837
#  3. Broncos D/ST              | Score: 0.822
#  4. Vikings D/ST              | Score: 0.790
#  5. Ravens D/ST               | Score: 0.770
#  6. Seahawks D/ST             | Score: 0.737
#  7. Lions D/ST                | Score: 0.715
#  8. Patriots D/ST             | Score: 0.707
#  9. Colts D/ST                | Score: 0.602
# 10. Bills D/ST                | Score: 0.595
# 11. Eagles D/ST               | Score: 0.581
# 12. Giants D/ST               | Score: 0.577
# 13. Buccaneers D/ST           | Score: 0.537
# 14. Cardinals D/ST            | Score: 0.527
# 15. Chiefs D/ST               | Score: 0.476
# 16. Jets D/ST                 | Score: 0.457
# 17. Bears D/ST                | Score: 0.438
# 18. Rams D/ST                 | Score: 0.404
# 19. Packers D/ST              | Score: 0.386
# 20. Cowboys D/ST              | Score: 0.360
# 21. 49ers D/ST                | Score: 0.346
# 22. Dolphins D/ST             | Score: 0.335
# 23. Commanders D/ST           | Score: 0.306
#
# K RANKINGS:
# --------------------------------------------------
#  1. Chase McLaughlin          | Score: 0.933
#  2. Cameron Dicker            | Score: 0.902
#  3. Jake Bates                | Score: 0.876
#  4. Brandon Aubrey            | Score: 0.848
#  5. Jason Sanders             | Score: 0.758
#  6. Jake Elliott              | Score: 0.745
#  7. Tyler Bass                | Score: 0.725
#  8. Matt Gay                  | Score: 0.659
#  9. Tyler Loop                | Score: 0.632
# 10. Chris Boswell             | Score: 0.600
# 11. Harrison Butker           | Score: 0.587
# 12. Cairo Santos              | Score: 0.566
# 13. Ka'imi Fairbairn          | Score: 0.520
# 14. Joshua Karty              | Score: 0.500
# 15. Evan McPherson            | Score: 0.436
# 16. Wil Lutz                  | Score: 0.404
# 17. Brandon McManus           | Score: 0.398
# 18. Daniel Carlson            | Score: 0.380
# 19. Younghoe Koo              | Score: 0.341
#
# QB RANKINGS:
# --------------------------------------------------
#  1. Jayden Daniels            | Score: 0.924
#  2. Jalen Hurts               | Score: 0.918
#  3. Josh Allen                | Score: 0.917
#  4. Lamar Jackson             | Score: 0.891
#  5. Joe Burrow                | Score: 0.846
#  6. Baker Mayfield            | Score: 0.802
#  7. Patrick Mahomes           | Score: 0.797
#  8. Kyler Murray              | Score: 0.770
#  9. Bo Nix                    | Score: 0.745
# 10. Brock Purdy               | Score: 0.738
# 11. Justin Fields             | Score: 0.686
# 12. Justin Herbert            | Score: 0.661
# 13. Dak Prescott              | Score: 0.655
# 14. J.J. McCarthy             | Score: 0.638
# 15. Caleb Williams            | Score: 0.622
# 16. Trevor Lawrence           | Score: 0.565
# 17. Drake Maye                | Score: 0.536
# 18. C.J. Stroud               | Score: 0.531
# 19. Tua Tagovailoa            | Score: 0.530
# 20. Bryce Young               | Score: 0.510
# 21. Jordan Love               | Score: 0.490
# 22. Matthew Stafford          | Score: 0.483
# 23. Jared Goff                | Score: 0.479
# 24. Geno Smith                | Score: 0.430
# 25. Cameron Ward              | Score: 0.422
# 26. Michael Penix Jr.         | Score: 0.405
# 27. Sam Darnold               | Score: 0.378
# 28. Aaron Rodgers             | Score: 0.362
# 29. Shedeur Sanders           | Score: 0.314
# 30. Anthony Richardson Sr.    | Score: 0.270
#
# RB RANKINGS:
# --------------------------------------------------
#  1. Bijan Robinson            | Score: 0.971
#  2. Jahmyr Gibbs              | Score: 0.943
#  3. Saquon Barkley            | Score: 0.931
#  4. Christian McCaffrey       | Score: 0.931
#  5. De'Von Achane             | Score: 0.922
#  6. Bucky Irving              | Score: 0.911
#  7. Ashton Jeanty             | Score: 0.911
#  8. Jonathan Taylor           | Score: 0.903
#  9. Josh Jacobs               | Score: 0.892
# 10. Derrick Henry             | Score: 0.877
# 11. Chase Brown               | Score: 0.868
# 12. Kyren Williams            | Score: 0.842
# 13. James Cook                | Score: 0.829
# 14. Alvin Kamara              | Score: 0.818
# 15. Kenneth Walker III        | Score: 0.809
# 16. Omarion Hampton           | Score: 0.804
# 17. James Conner              | Score: 0.787
# 18. Chuba Hubbard             | Score: 0.786
# 19. Breece Hall               | Score: 0.740
# 20. D'Andre Swift             | Score: 0.727
# 21. Aaron Jones Sr.           | Score: 0.700
# 22. TreVeyon Henderson        | Score: 0.693
# 23. David Montgomery          | Score: 0.688
# 24. Kaleb Johnson             | Score: 0.676
# 25. RJ Harvey                 | Score: 0.671
# 26. Isiah Pacheco             | Score: 0.663
# 27. Tony Pollard              | Score: 0.648
# 28. Brian Robinson Jr.        | Score: 0.611
# 29. Jaylen Warren             | Score: 0.603
# 30. Tyrone Tracy Jr.          | Score: 0.602
# 31. Javonte Williams          | Score: 0.579
# 32. J.K. Dobbins              | Score: 0.565
# 33. Rhamondre Stevenson       | Score: 0.561
# 34. Joe Mixon                 | Score: 0.560
# 35. Austin Ekeler             | Score: 0.547
# 36. Tyjae Spears              | Score: 0.525
# 37. Travis Etienne Jr.        | Score: 0.521
# 38. Quinshon Judkins          | Score: 0.511
# 39. Tank Bigsby               | Score: 0.499
# 40. Trey Benson               | Score: 0.490
# 41. Rachaad White             | Score: 0.486
# 42. Zach Charbonnet           | Score: 0.476
# 43. Jordan Mason              | Score: 0.475
# 44. Justice Hill              | Score: 0.463
# 45. Cam Skattebo              | Score: 0.458
# 46. Tyler Allgeier            | Score: 0.443
# 47. Jerome Ford               | Score: 0.440
# 48. Dylan Sampson             | Score: 0.407
# 49. Jaylen Wright             | Score: 0.395
# 50. Ray Davis                 | Score: 0.386
# 51. Roschon Johnson           | Score: 0.363
# 52. Braelon Allen             | Score: 0.361
# 53. Nick Chubb                | Score: 0.357
# 54. Kareem Hunt               | Score: 0.347
# 55. Isaac Guerendo            | Score: 0.342
# 56. Woody Marks               | Score: 0.337
# 57. Bhayshul Tuten            | Score: 0.330
# 58. MarShawn Lloyd            | Score: 0.314
# 59. Blake Corum               | Score: 0.308
# 60. Jaydon Blue               | Score: 0.301
# 61. Najee Harris              | Score: 0.241
#
# TE RANKINGS:
# --------------------------------------------------
#  1. Brock Bowers              | Score: 0.946
#  2. Trey McBride              | Score: 0.935
#  3. George Kittle             | Score: 0.913
#  4. Sam LaPorta               | Score: 0.855
#  5. Travis Kelce              | Score: 0.792
#  6. David Njoku               | Score: 0.778
#  7. T.J. Hockenson            | Score: 0.776
#  8. Mark Andrews              | Score: 0.753
#  9. Evan Engram               | Score: 0.739
# 10. Tucker Kraft              | Score: 0.690
# 11. Colston Loveland          | Score: 0.666
# 12. Dallas Goedert            | Score: 0.664
# 13. Dalton Kincaid            | Score: 0.591
# 14. Hunter Henry              | Score: 0.563
# 15. Jake Ferguson             | Score: 0.552
# 16. Tyler Warren              | Score: 0.548
# 17. Chig Okonkwo              | Score: 0.518
# 18. Kyle Pitts Sr.            | Score: 0.465
# 19. Zach Ertz                 | Score: 0.447
# 20. Brenton Strange           | Score: 0.439
# 21. Jonnu Smith               | Score: 0.404
# 22. Pat Freiermuth            | Score: 0.361
# 23. Cade Otton                | Score: 0.345
# 24. Darren Waller             | Score: 0.315
# 25. Mike Gesicki              | Score: 0.297
# 26. Isaiah Likely             | Score: 0.265
#
# WR RANKINGS:
# --------------------------------------------------
#  1. Ja'Marr Chase             | Score: 0.968
#  2. CeeDee Lamb               | Score: 0.952
#  3. Puka Nacua                | Score: 0.934
#  4. Amon-Ra St. Brown         | Score: 0.919
#  5. Nico Collins              | Score: 0.909
#  6. Brian Thomas Jr.          | Score: 0.902
#  7. Tee Higgins               | Score: 0.883
#  8. Drake London              | Score: 0.882
#  9. Justin Jefferson          | Score: 0.876
# 10. Davante Adams             | Score: 0.858
# 11. Malik Nabers              | Score: 0.842
# 12. A.J. Brown                | Score: 0.828
# 13. Jaxon Smith-Njigba        | Score: 0.818
# 14. DK Metcalf                | Score: 0.793
# 15. Xavier Worthy             | Score: 0.782
# 16. Mike Evans                | Score: 0.782
# 17. Marvin Harrison Jr.       | Score: 0.780
# 18. Tyreek Hill               | Score: 0.780
# 19. Ladd McConkey             | Score: 0.773
# 20. Garrett Wilson            | Score: 0.771
# 21. DJ Moore                  | Score: 0.763
# 22. Zay Flowers               | Score: 0.731
# 23. Courtland Sutton          | Score: 0.723
# 24. Calvin Ridley             | Score: 0.719
# 25. Jerry Jeudy               | Score: 0.719
# 26. Jaylen Waddle             | Score: 0.683
# 27. Jakobi Meyers             | Score: 0.681
# 28. DeVonta Smith             | Score: 0.680
# 29. George Pickens            | Score: 0.674
# 30. Jameson Williams          | Score: 0.667
# 31. Tetairoa McMillan         | Score: 0.658
# 32. Travis Hunter             | Score: 0.647
# 33. Rome Odunze               | Score: 0.644
# 34. Terry McLaurin            | Score: 0.629
# 35. Chris Olave               | Score: 0.603
# 36. Matthew Golden            | Score: 0.590
# 37. Cooper Kupp               | Score: 0.572
# 38. Ricky Pearsall            | Score: 0.556
# 39. Deebo Samuel              | Score: 0.556
# 40. Rashee Rice               | Score: 0.552
# 41. Rashid Shaheed            | Score: 0.544
# 42. Khalil Shakir             | Score: 0.530
# 43. Keenan Allen              | Score: 0.525
# 44. Keon Coleman              | Score: 0.515
# 45. Jauan Jennings            | Score: 0.500
# 46. Stefon Diggs              | Score: 0.493
# 47. Michael Pittman Jr.       | Score: 0.493
# 48. Jayden Higgins            | Score: 0.491
# 49. Adam Thielen              | Score: 0.489
# 50. Josh Downs                | Score: 0.471
# 51. Xavier Legette            | Score: 0.449
# 52. Cedric Tillman            | Score: 0.443
# 53. Marvin Mims Jr.           | Score: 0.442
# 54. Jordan Addison            | Score: 0.431
# 55. Darnell Mooney            | Score: 0.427
# 56. Jayden Reed               | Score: 0.424
# 57. Wan'Dale Robinson         | Score: 0.420
# 58. Emeka Egbuka              | Score: 0.412
# 59. Rashod Bateman            | Score: 0.409
# 60. Jack Bech                 | Score: 0.404
# 61. Romeo Doubs               | Score: 0.400
# 62. Luther Burden III         | Score: 0.381
# 63. Tyler Lockett             | Score: 0.375
# 64. Chris Godwin              | Score: 0.367
# 65. Hollywood Brown           | Score: 0.366
# 66. Christian Kirk            | Score: 0.363
# 67. Tre Harris                | Score: 0.361
# 68. Kyle Williams             | Score: 0.343
# 69. Quentin Johnston          | Score: 0.341
# 70. Jalen McMillan            | Score: 0.327
# 71. DeAndre Hopkins           | Score: 0.319
# 72. Brandon Aiyuk             | Score: 0.176

# %%
results_df
# Out:
#                     name position  composite_score  production_score  \
# 0           Malik Nabers       WR            0.842             0.944
# 1          Derrick Henry       RB            0.877             0.836
# 2    Marvin Harrison Jr.       WR            0.780             0.764
# 3        Omarion Hampton       RB            0.804             0.754
# 4          Xavier Worthy       WR            0.782             0.750
# ..                   ...      ...              ...               ...
# 226            Rams D/ST     D/ST            0.404             0.261
# 227      Shedeur Sanders       QB            0.314             0.033
# 228        Tyler Lockett       WR            0.375             0.125
# 229           Geno Smith       QB            0.430             0.233
# 230          Romeo Doubs       WR            0.400             0.153
#
#      reliability_score  sentiment_score  value_score  position_rank
# 0                0.816              0.5        0.694              5
# 1                0.996              0.8        0.607             11
# 2                0.941              0.5        0.375             18
# 3                0.936              0.7        0.590             16
# 4                0.943              0.6        0.333             19
# ..                 ...              ...          ...            ...
# 226              0.496              0.5        1.000             18
# 227              0.610              0.5        0.667             30
# 228              0.610              0.5        0.986             64
# 229              0.611              0.5        1.000             24
# 230              0.610              0.6        1.000             62
#
# [231 rows x 8 columns]

# %%
from espn_api.football import League
league = League(league_id=600021088, year=2025)
print(league)
# Out:
# League(600021088, 2025)

# %%
for player in league.teams[0].roster:
    print(player.name)
    print(evaluate_player(player.name, stats_df, sentiment_df))
# Out:
# Malik Nabers
# {'name': 'Malik Nabers', 'position': 'WR', 'composite_score': np.float64(0.842), 'production_score': np.float64(0.944), 'reliability_score': np.float64(0.816), 'sentiment_score': 0.5, 'value_score': np.float64(0.694), 'position_rank': 5}
# Derrick Henry
# {'name': 'Derrick Henry', 'position': 'RB', 'composite_score': np.float64(0.877), 'production_score': np.float64(0.836), 'reliability_score': np.float64(0.996), 'sentiment_score': 0.8, 'value_score': np.float64(0.607), 'position_rank': 11}
# Marvin Harrison Jr.
# {'name': 'Marvin Harrison Jr.', 'position': 'WR', 'composite_score': np.float64(0.78), 'production_score': np.float64(0.764), 'reliability_score': np.float64(0.941), 'sentiment_score': 0.5, 'value_score': np.float64(0.375), 'position_rank': 18}
# Omarion Hampton
# {'name': 'Omarion Hampton', 'position': 'RB', 'composite_score': np.float64(0.804), 'production_score': np.float64(0.754), 'reliability_score': np.float64(0.936), 'sentiment_score': 0.7, 'value_score': np.float64(0.59), 'position_rank': 16}
# Xavier Worthy
# {'name': 'Xavier Worthy', 'position': 'WR', 'composite_score': np.float64(0.782), 'production_score': np.float64(0.75), 'reliability_score': np.float64(0.943), 'sentiment_score': 0.6, 'value_score': np.float64(0.333), 'position_rank': 19}
# DeVonta Smith
# {'name': 'DeVonta Smith', 'position': 'WR', 'composite_score': np.float64(0.68), 'production_score': np.float64(0.625), 'reliability_score': np.float64(0.872), 'sentiment_score': 0.5, 'value_score': np.float64(0.25), 'position_rank': 28}
# Brian Robinson Jr.
# {'name': 'Brian Robinson Jr.', 'position': 'RB', 'composite_score': np.float64(0.611), 'production_score': np.float64(0.541), 'reliability_score': np.float64(0.788), 'sentiment_score': 0.5, 'value_score': np.float64(0.295), 'position_rank': 29}
# Colston Loveland
# {'name': 'Colston Loveland', 'position': 'TE', 'composite_score': np.float64(0.666), 'production_score': np.float64(0.577), 'reliability_score': np.float64(0.799), 'sentiment_score': 0.8, 'value_score': np.float64(0.346), 'position_rank': 12}
# Jordan Mason
# {'name': 'Jordan Mason', 'position': 'RB', 'composite_score': np.float64(0.475), 'production_score': np.float64(0.311), 'reliability_score': np.float64(0.727), 'sentiment_score': 0.6, 'value_score': np.float64(0.098), 'position_rank': 43}
# Jordan Love
# {'name': 'Jordan Love', 'position': 'QB', 'composite_score': np.float64(0.49), 'production_score': np.float64(0.3), 'reliability_score': np.float64(0.719), 'sentiment_score': 0.6, 'value_score': np.float64(0.567), 'position_rank': 22}
# Hunter Henry
# {'name': 'Hunter Henry', 'position': 'TE', 'composite_score': np.float64(0.563), 'production_score': np.float64(0.462), 'reliability_score': np.float64(0.651), 'sentiment_score': 0.7, 'value_score': np.float64(0.692), 'position_rank': 15}
# Steelers D/ST
# {'name': 'Steelers D/ST', 'position': 'D/ST', 'composite_score': np.float64(0.837), 'production_score': np.float64(0.957), 'reliability_score': np.float64(0.857), 'sentiment_score': 0.5, 'value_score': np.float64(0.174), 'position_rank': 2}
# Chase McLaughlin
# {'name': 'Chase McLaughlin', 'position': 'K', 'composite_score': np.float64(0.933), 'production_score': np.float64(1.0), 'reliability_score': np.float64(0.977), 'sentiment_score': 0.8, 'value_score': np.float64(0.211), 'position_rank': 1}
# Drake Maye
# {'name': 'Drake Maye', 'position': 'QB', 'composite_score': np.float64(0.536), 'production_score': np.float64(0.367), 'reliability_score': np.float64(0.717), 'sentiment_score': 0.7, 'value_score': np.float64(0.633), 'position_rank': 20}
# Justin Herbert
# {'name': 'Justin Herbert', 'position': 'QB', 'composite_score': np.float64(0.661), 'production_score': np.float64(0.633), 'reliability_score': np.float64(0.818), 'sentiment_score': 0.5, 'value_score': np.float64(0.167), 'position_rank': 12}

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def custom_scale(values, target_min=0.65, target_max=0.95):
    """Scale values to be mostly between target_min and target_max"""
    # Use 5th and 95th percentiles as reference points instead of absolute min/max
    p5, p95 = np.percentile(values, [5, 95])
    
    # Linear scaling based on percentiles
    scaled = (values - p5) / (p95 - p5) * (target_max - target_min) + target_min
    
    # Gentle clipping to avoid extreme outliers
    return np.clip(scaled, target_min - 0.05, target_max + 0.05)

def evaluate_teams(league,stats_df, sentiment_df):
    team_evaluations = []
    for team in league.teams:
        wrs, qbs, tes, rbs, dsts, k = [], [], [], [], [], []
        for player in team.roster:
            eval = evaluate_player(player.name, stats_df, sentiment_df)
            res = [eval['name'], eval['composite_score']]
            if eval['position'] == 'WR':
                wrs.append(res)
            elif eval['position'] == 'QB':
                qbs.append(res)
            elif eval['position'] == 'TE':
                tes.append(res)
            elif eval['position'] == 'RB':
                rbs.append(res)
            elif eval['position'] == 'D/ST':
                dsts.append(res)
            elif eval['position'] == 'K':
                k.append(res)
        sorted_wrs = sorted(wrs, key=lambda x: x[1], reverse=True)
        sorted_rbs = sorted(rbs, key=lambda x: x[1], reverse=True)
        sorted_tes = sorted(tes, key=lambda x: x[1], reverse=True)
        sorted_qbs = sorted(qbs, key=lambda x: x[1], reverse=True)
        sorted_dsts = sorted(dsts, key=lambda x: x[1], reverse=True)
        sorted_k = sorted(k, key=lambda x: x[1], reverse=True)

        starting_wr_score = np.mean([x[1] for x in sorted_wrs[:2]])
        starting_rb_score = np.mean([x[1] for x in sorted_rbs[:2]])
        starting_te_score = sorted_tes[0][1]
        starting_qbs_score = sorted_qbs[0][1]
        dst_score = np.mean([x[1] for x in sorted_dsts])
        k_score = np.mean([x[1] for x in sorted_k])

        bench_wr_score, bench_rb_score, bench_te_score, bench_qbs_score, bench_k_score, bench_dst_score = 0,0,0,0,0,0
        if len(sorted_wrs) > 3: 
            bench_wr_score = np.mean([x[1] for x in sorted_wrs[2:]])
        if len(sorted_rbs) > 3:
            bench_rb_score = np.mean([x[1] for x in sorted_rbs[2:]])
        if len(sorted_tes) > 1:
            bench_te_score = np.mean([x[1] for x in sorted_tes[1:]])
        if len(sorted_qbs) > 1:
            bench_qbs_score = np.mean([x[1] for x in sorted_qbs[1:]])

       

        team_stats = {
            'team_name': team.team_name,
            'team_id': team.team_id,
            'starting_wr_score': starting_wr_score,
            'starting_rb_score': starting_rb_score,
            'starting_te_score': starting_te_score,
            'starting_qbs_score': starting_qbs_score,
            'dst_score': dst_score,
            'k_score': k_score,
            'bench_wr_score': bench_wr_score,
            'bench_rb_score': bench_rb_score,
            'bench_te_score': bench_te_score,
            'bench_qbs_score': bench_qbs_score,
        }
        position_weights = {
            'starting_wr': {'weight': 3, 'count': 2},
            'starting_rb': {'weight': 2.5, 'count': 2}, 
            'starting_te': {'weight': 1.0, 'count': 1},
            'starting_qbs': {'weight': 1.0, 'count': 1},
            'dst': {'weight': 0.5, 'count': 1},
            'k': {'weight': 0.5, 'count': 1},
            'bench_wr': {'weight': 0.25, 'count': len(sorted_wrs) - 2},
            'bench_rb': {'weight': 0.25, 'count': len(sorted_rbs) - 2},
            'bench_te': {'weight': 0.1, 'count': len(sorted_tes) - 1},
            'bench_qbs': {'weight': 0.1, 'count': len(sorted_qbs) - 1},
        }

        total_weighted_score = 0
        total_weight = 0

        for pos, config in position_weights.items():
            score = team_stats[f'{pos}_score']
            weight = config['weight']
            count = max(config['count'], 0)  
            
            contribution = score * weight * count
            total_weighted_score += contribution
            total_weight += weight * count

        overall_score = total_weighted_score / total_weight if total_weight > 0 else 0
        team_stats['overall_score'] = overall_score
        team_evaluations.append(team_stats)
        # print(json.dumps(team_stats, indent=4))
        # print()
    
    team_df = pd.DataFrame(team_evaluations)
    scaler = MinMaxScaler(feature_range=(0.6, 1))
    team_df['overall_score'] = custom_scale(team_df['overall_score'].values)    
    return team_df

evaluated = evaluate_teams(league, stats_df, sentiment_df)

# %%
evaluated
# Out:
#                          team_name  team_id  starting_wr_score  \
# 0                        FC Skanda        1             0.7940
# 1                      Team Venkat        2             0.8935
# 2                          Team To        3             0.7300
# 3                           Cocsaj        4             0.8155
# 4    Deshaun Dont Touchdown There!        5             0.7915
# 5                   Rashid Shannid        6             0.9010
# 6                  Big D Dorthouse        7             0.6565
# 7                         Team Zim        8             0.7720
# 8                    Team Khachane        9             0.8630
# 9                      Team Nguyen       10             0.6865
# 10  Bustin' Tucker's Happy Endings       11             0.8915
# 11                      Team Arani       12             0.8455
#
#     starting_rb_score  starting_te_score  starting_qbs_score  dst_score  \
# 0              0.8220              0.643               0.629      0.803
# 1              0.7495              0.749               0.735      0.755
# 2              0.9185              0.556               0.884      0.692
# 3              0.8580              0.711               0.756      0.830
# 4              0.7895              0.923               0.425      0.590
# 5              0.7515              0.646               0.855      0.584
# 6              0.9040              0.813               0.883      0.349
# 7              0.8035              0.886               0.705      0.718
# 8              0.6915              0.664               0.799      0.575
# 9              0.8750              0.910               0.637      0.686
# 10             0.8290              0.704               0.758      0.784
# 11             0.7100              0.737               0.893      0.741
#
#     k_score  bench_wr_score  bench_rb_score  bench_te_score  bench_qbs_score  \
# 0     0.894        0.700000        0.515000           0.565           0.5075
# 1     0.708        0.448800        0.000000           0.350           0.0000
# 2     0.571        0.495000        0.584667           0.000           0.0000
# 3     0.561        0.572667        0.465500           0.571           0.4650
# 4     0.805        0.485400        0.534500           0.000           0.0000
# 5     0.861        0.473500        0.507750           0.000           0.0000
# 6     0.659        0.472000        0.408333           0.746           0.5250
# 7     0.712        0.502667        0.485250           0.000           0.0000
# 8     0.829        0.480667        0.000000           0.000           0.6550
# 9     0.512        0.476750        0.432000           0.000           0.0000
# 10    0.569        0.537333        0.359500           0.523           0.5750
# 11    0.734        0.499333        0.470500           0.462           0.6280
#
#     overall_score
# 0        0.842444
# 1        0.819811
# 2        0.801673
# 3        0.918867
# 4        0.686867
# 5        0.864394
# 6        0.665373
# 7        0.750939
# 8        0.713732
# 9        0.631211
# 10       0.988052
# 11       0.788688

# %%
def add_league_comparisons(team_df):
    """
    Add league-wide statistical comparisons for each position and overall scores.
    """
    
    position_cols = [
        'starting_wr_score', 'starting_rb_score', 'starting_te_score', 
        'starting_qbs_score', 'dst_score', 'k_score',
        'bench_wr_score', 'bench_rb_score', 'bench_te_score', 
        'bench_qbs_score', 
        'overall_score'
    ]
    
    league_stats = {}
    for col in position_cols:
        league_stats[col] = {
            'mean': team_df[col].mean(),
            'std': team_df[col].std(),
            'min': team_df[col].min(),
            'max': team_df[col].max(),
            'median': team_df[col].median()
        }
    
    comparison_df = team_df.copy()[position_cols]
   
    comparison_df['team_name'] = team_df['team_name']
    comparison_df['team_id'] = team_df['team_id']
    
    for col in position_cols:
        zscore = (team_df[col] - league_stats[col]['mean']) / league_stats[col]['std']
        comparison_df[f'{col}_percentile'] = team_df[col].rank(pct=True) * 100
        comparison_df[f'{col}_tier'] = zscore.apply(classify_tier)    
    return comparison_df, league_stats

def classify_tier(zscore):
    """Classify performance into tiers based on z-score"""
    if zscore >= 1.5:
        return "A"
    elif zscore >= 0.5:
        return "B"
    elif zscore >= -0.5:
        return "C"
    elif zscore >= -1.5:
        return "D"
    else:
        return "F"

evaluated_stats = add_league_comparisons(evaluated)[0]
cols = evaluated_stats.columns.tolist()
for col in ['overall_score_percentile', 'overall_score', 'overall_score_tier', 'team_name', 'team_id', ]:
    if col in cols:
        cols.insert(0, cols.pop(cols.index(col)))
evaluated_stats = evaluated_stats[cols]
evaluated_stats.T
# Out:
#                                       0            1          2          3   \
# team_id                                1            2          3          4
# team_name                      FC Skanda  Team Venkat    Team To     Cocsaj
# overall_score_tier                     B            C          C          B
# overall_score                   0.842444     0.819811   0.801673   0.918867
# overall_score_percentile            75.0    66.666667  58.333333  91.666667
# starting_wr_score                  0.794       0.8935       0.73     0.8155
# starting_rb_score                  0.822       0.7495     0.9185      0.858
# starting_te_score                  0.643        0.749      0.556      0.711
# starting_qbs_score                 0.629        0.735      0.884      0.756
# dst_score                          0.803        0.755      0.692       0.83
# k_score                            0.894        0.708      0.571      0.561
# bench_wr_score                       0.7       0.4488      0.495   0.572667
# bench_rb_score                     0.515          0.0   0.584667     0.4655
# bench_te_score                     0.565         0.35        0.0      0.571
# bench_qbs_score                   0.5075          0.0        0.0      0.465
# starting_wr_score_percentile        50.0    91.666667       25.0  58.333333
# starting_wr_score_tier                 C            B          D          C
# starting_rb_score_percentile   58.333333         25.0      100.0       75.0
# starting_rb_score_tier                 C            D          B          B
# starting_te_score_percentile   16.666667    66.666667   8.333333       50.0
# starting_te_score_tier                 D            C          F          C
# starting_qbs_score_percentile  16.666667    41.666667  91.666667       50.0
# starting_qbs_score_tier                D            C          B          C
# dst_score_percentile           91.666667         75.0       50.0      100.0
# dst_score_tier                         B            B          C          B
# k_score_percentile                 100.0         50.0  33.333333  16.666667
# k_score_tier                           B            C          D          D
# bench_wr_score_percentile          100.0     8.333333  58.333333  91.666667
# bench_wr_score_tier                    A            D          C          B
# bench_rb_score_percentile      83.333333         12.5      100.0       50.0
# bench_rb_score_tier                    B            F          B          C
# bench_te_score_percentile      83.333333    58.333333  29.166667  91.666667
# bench_te_score_tier                    B            C          D          B
# bench_qbs_score_percentile     66.666667    29.166667  29.166667  58.333333
# bench_qbs_score_tier                   B            D          D          B
#
#                                                           4               5   \
# team_id                                                    5               6
# team_name                      Deshaun Dont Touchdown There!  Rashid Shannid
# overall_score_tier                                         D               B
# overall_score                                       0.686867        0.864394
# overall_score_percentile                                25.0       83.333333
# starting_wr_score                                     0.7915           0.901
# starting_rb_score                                     0.7895          0.7515
# starting_te_score                                      0.923           0.646
# starting_qbs_score                                     0.425           0.855
# dst_score                                               0.59           0.584
# k_score                                                0.805           0.861
# bench_wr_score                                        0.4854          0.4735
# bench_rb_score                                        0.5345         0.50775
# bench_te_score                                           0.0             0.0
# bench_qbs_score                                          0.0             0.0
# starting_wr_score_percentile                       41.666667           100.0
# starting_wr_score_tier                                     C               B
# starting_rb_score_percentile                       41.666667       33.333333
# starting_rb_score_tier                                     C               D
# starting_te_score_percentile                           100.0            25.0
# starting_te_score_tier                                     A               D
# starting_qbs_score_percentile                       8.333333            75.0
# starting_qbs_score_tier                                    F               B
# dst_score_percentile                               33.333333            25.0
# dst_score_tier                                             D               D
# k_score_percentile                                      75.0       91.666667
# k_score_tier                                               B               B
# bench_wr_score_percentile                               50.0            25.0
# bench_wr_score_tier                                        C               D
# bench_rb_score_percentile                          91.666667            75.0
# bench_rb_score_tier                                        B               B
# bench_te_score_percentile                          29.166667       29.166667
# bench_te_score_tier                                        D               D
# bench_qbs_score_percentile                         29.166667       29.166667
# bench_qbs_score_tier                                       D               D
#
#                                             6          7              8   \
# team_id                                      7          8              9
# team_name                      Big D Dorthouse   Team Zim  Team Khachane
# overall_score_tier                           D          C              D
# overall_score                         0.665373   0.750939       0.713732
# overall_score_percentile             16.666667  41.666667      33.333333
# starting_wr_score                       0.6565      0.772          0.863
# starting_rb_score                        0.904     0.8035         0.6915
# starting_te_score                        0.813      0.886          0.664
# starting_qbs_score                       0.883      0.705          0.799
# dst_score                                0.349      0.718          0.575
# k_score                                  0.659      0.712          0.829
# bench_wr_score                           0.472   0.502667       0.480667
# bench_rb_score                        0.408333    0.48525            0.0
# bench_te_score                           0.746        0.0            0.0
# bench_qbs_score                          0.525        0.0          0.655
# starting_wr_score_percentile          8.333333  33.333333           75.0
# starting_wr_score_tier                       F          C              B
# starting_rb_score_percentile         91.666667       50.0       8.333333
# starting_rb_score_tier                       B          C              F
# starting_te_score_percentile              75.0  83.333333      33.333333
# starting_te_score_tier                       B          B              D
# starting_qbs_score_percentile        83.333333  33.333333      66.666667
# starting_qbs_score_tier                      B          C              C
# dst_score_percentile                  8.333333  58.333333      16.666667
# dst_score_tier                               F          C              D
# k_score_percentile                   41.666667  58.333333      83.333333
# k_score_tier                                 C          C              B
# bench_wr_score_percentile            16.666667       75.0      41.666667
# bench_wr_score_tier                          D          C              C
# bench_rb_score_percentile            33.333333  66.666667           12.5
# bench_rb_score_tier                          C          C              F
# bench_te_score_percentile                100.0  29.166667      29.166667
# bench_te_score_tier                          A          D              D
# bench_qbs_score_percentile                75.0  29.166667          100.0
# bench_qbs_score_tier                         B          D              B
#
#                                         9                               10  \
# team_id                                 10                              11
# team_name                      Team Nguyen  Bustin' Tucker's Happy Endings
# overall_score_tier                       D                               A
# overall_score                     0.631211                        0.988052
# overall_score_percentile          8.333333                           100.0
# starting_wr_score                   0.6865                          0.8915
# starting_rb_score                    0.875                           0.829
# starting_te_score                     0.91                           0.704
# starting_qbs_score                   0.637                           0.758
# dst_score                            0.686                           0.784
# k_score                              0.512                           0.569
# bench_wr_score                     0.47675                        0.537333
# bench_rb_score                       0.432                          0.3595
# bench_te_score                         0.0                           0.523
# bench_qbs_score                        0.0                           0.575
# starting_wr_score_percentile     16.666667                       83.333333
# starting_wr_score_tier                   D                               B
# starting_rb_score_percentile     83.333333                       66.666667
# starting_rb_score_tier                   B                               C
# starting_te_score_percentile     91.666667                       41.666667
# starting_te_score_tier                   B                               C
# starting_qbs_score_percentile         25.0                       58.333333
# starting_qbs_score_tier                  D                               C
# dst_score_percentile             41.666667                       83.333333
# dst_score_tier                           C                               B
# k_score_percentile                8.333333                            25.0
# k_score_tier                             D                               D
# bench_wr_score_percentile        33.333333                       83.333333
# bench_wr_score_tier                      D                               C
# bench_rb_score_percentile        41.666667                            25.0
# bench_rb_score_tier                      C                               C
# bench_te_score_percentile        29.166667                            75.0
# bench_te_score_tier                      D                               B
# bench_qbs_score_percentile       29.166667                       83.333333
# bench_qbs_score_tier                     D                               B
#
#                                        11
# team_id                                12
# team_name                      Team Arani
# overall_score_tier                      C
# overall_score                    0.788688
# overall_score_percentile             50.0
# starting_wr_score                  0.8455
# starting_rb_score                    0.71
# starting_te_score                   0.737
# starting_qbs_score                  0.893
# dst_score                           0.741
# k_score                             0.734
# bench_wr_score                   0.499333
# bench_rb_score                     0.4705
# bench_te_score                      0.462
# bench_qbs_score                     0.628
# starting_wr_score_percentile    66.666667
# starting_wr_score_tier                  B
# starting_rb_score_percentile    16.666667
# starting_rb_score_tier                  D
# starting_te_score_percentile    58.333333
# starting_te_score_tier                  C
# starting_qbs_score_percentile       100.0
# starting_qbs_score_tier                 B
# dst_score_percentile            66.666667
# dst_score_tier                          C
# k_score_percentile              66.666667
# k_score_tier                            C
# bench_wr_score_percentile       66.666667
# bench_wr_score_tier                     C
# bench_rb_score_percentile       58.333333
# bench_rb_score_tier                     C
# bench_te_score_percentile       66.666667
# bench_te_score_tier                     B
# bench_qbs_score_percentile      91.666667
# bench_qbs_score_tier                    B

# %%
evaluated_stats.to_csv('evaluated_stats.csv', index=False)
