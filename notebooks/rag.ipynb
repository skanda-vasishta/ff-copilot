# %%
import pandas as pd

# %%
sentiment_df = pd.read_csv('player_scraped_info.csv')
stats_df = pd.read_csv('player_stats.csv')

# %%
combined_df = stats_df.merge(
    sentiment_df, 
    on=['playerId', 'name'],  
    how='left'  
)

# %%
def create_docs(row):
    """
    Create detailed natural language documents using only the specified columns
    """
    
    
    doc_text = f"""
        PLAYER PROFILE: {row['name']} (ID: {row.get('playerId', 'Unknown')})

        BASIC INFORMATION:
        - Position: {row['position']}
        - Team: {row.get('proTeam', 'Unknown')}
        - Position Rank: {row.get('posRank', 'Unranked')}
        - Current Lineup Slot: {row.get('lineupSlot', 'Not set')}
        - Acquisition Method: {row.get('acquisitionType', 'Unknown')}
        - Team Assignment: Team #{row.get('onTeamId', 'Unknown')}

        ELIGIBLE POSITIONS:
        - Can play in slots: {row.get('eligibleSlots', 'No data available')}

        HEALTH STATUS:
        - Injury Status: {row.get('injuryStatus', 'Unknown')}
        - Currently Injured: {'Yes' if row.get('injured', False) else 'No'}

        FANTASY PERFORMANCE:
        - Total Points This Season: {row.get('total_points', 0)} points
        - Average Points Per Game: {row.get('avg_points', 0)} points
        - Projected Season Total: {row.get('projected_total_points', 0)} points
        - Projected Weekly Average: {row.get('projected_avg_points', 0)} points

        OWNERSHIP METRICS:
        - League Ownership: {row.get('percent_owned', 0)}% of leagues own this player
        - Start Rate: {row.get('percent_started', 0)}% of owners start this player
        - Popularity Assessment: {'Widely owned popular player' if row.get('percent_owned', 0) > 70 else 'Moderately owned' if row.get('percent_owned', 0) > 30 else 'Lightly owned sleeper candidate'}

    """.strip()
            

        
    return doc_text

# %%
combined_df['stats_doc'] = combined_df.apply(create_docs, axis=1)

combined_df.head()
# Out:
#    playerId                 name posRank  \
# 0   4595348         Malik Nabers      []
# 1   3043078        Derrick Henry      []
# 2   4432708  Marvin Harrison Jr.      []
# 3   4685382      Omarion Hampton      []
# 4   4683062        Xavier Worthy      []
#
#                                        eligibleSlots lineupSlot  \
# 0  ["RB/WR", "WR", "WR/TE", "RB/WR/TE", "OP", "BE...         WR
# 1      ["RB", "RB/WR", "RB/WR/TE", "OP", "BE", "IR"]         RB
# 2  ["RB/WR", "WR", "WR/TE", "RB/WR/TE", "OP", "BE...         WR
# 3  ["Rookie", "RB", "RB/WR", "RB/WR/TE", "OP", "B...         RB
# 4  ["RB/WR", "WR", "WR/TE", "RB/WR/TE", "OP", "BE...   RB/WR/TE
#
#   acquisitionType proTeam  onTeamId position  injuryStatus  ...  \
# 0           DRAFT     NYG       1.0       WR  QUESTIONABLE  ...
# 1           DRAFT     BAL       1.0       RB        ACTIVE  ...
# 2           DRAFT     ARI       1.0       WR        ACTIVE  ...
# 3           DRAFT     LAC       1.0       RB        ACTIVE  ...
# 4           DRAFT      KC       1.0       WR        ACTIVE  ...
#
#    projected_total_points  projected_avg_points  percent_owned  \
# 0                  300.07                 17.65          99.80
# 1                  280.71                 16.51          99.82
# 2                  240.02                 14.12          96.54
# 3                  262.76                 15.46          94.60
# 4                  239.57                 14.09          96.65
#
#    percent_started                                              stats  \
# 0            98.07  {"1": {"projected_points": 19.02, "projected_b...
# 1            97.98  {"1": {"projected_points": 16.05, "projected_b...
# 2            73.94  {"1": {"projected_points": 13.93, "projected_b...
# 3            73.53  {"1": {"projected_points": 14.99, "projected_b...
# 4            74.63  {"1": {"projected_points": 17.15, "projected_b...
#
#                                          reddit_text  \
# 0  Title: Giants' Malik Nabers Taken to Locker Ro...
# 1  Title: 2025 League-Winning Draft Strategies - ...
# 2  Title: Is Marvin Harrison Jr. going to be as a...
# 3  Title: What is the earliest you are willing to...
# 4  Title: Chiefs WR Xavier Worthy, who left yeste...
#
#                                    fantasy_pros_text  \
# 0  Malik Nabers exploded in his rookie season as ...
# 1  The BIG DAWG KEEPS EATING! Some players are ju...
# 2  Marvin Harrison Jr. didn't come close to livin...
# 3  Hampton lands with the Bolts after hearing his...
# 4  Add Xavier Worthy to the list of disappointing...
#
#                                            espn_text  \
# 0  ESPN Fantasy Projection\n\n:\n\nNabers is comi...
# 1  News\n\n:\n\n2 days ago\n\nHenry and other key...
# 2  News\n\n:\n\n2 days ago\n\nHarrison (knee) is ...
# 3  ESPN Fantasy Projection\n\n:\n\nHampton was se...
# 4  News\n\n:\n\n7 days ago\n\nCoach Andy Reid rev...
#
#                                            sentiment  \
# 0  ```json\n{\n    "reddit_summary": "The Reddit ...
# 1  ```json\n{\n    "reddit_summary": "The discuss...
# 2  ```json\n{\n    "reddit_summary": "Reddit disc...
# 3  ```json\n{\n    "reddit_summary": "The Reddit ...
# 4  ```json\n{\n    "reddit_summary": "The discuss...
#
#                                            stats_doc
# 0  PLAYER PROFILE: Malik Nabers (ID: 4595348)\n\n...
# 1  PLAYER PROFILE: Derrick Henry (ID: 3043078)\n\...
# 2  PLAYER PROFILE: Marvin Harrison Jr. (ID: 44327...
# 3  PLAYER PROFILE: Omarion Hampton (ID: 4685382)\...
# 4  PLAYER PROFILE: Xavier Worthy (ID: 4683062)\n\...
#
# [5 rows x 23 columns]

# %%
cols_to_drop = ['stats', 'sentiment', 'posRank', 'eligibleSlots', 'lineupSlot',
       'acquisitionType', 'proTeam', 'onTeamId', 'position', 'injuryStatus',
       'injured', 'total_points', 'avg_points', 'projected_total_points', 'projected_avg_points', 'percent_owned', 'percent_started']

existing_cols = [col for col in cols_to_drop if col in combined_df.columns]
if existing_cols:
    combined_df.drop(columns=existing_cols, inplace=True)
else:
    print("None of the specified columns to drop are present in the DataFrame.")
combined_df.columns
combined_df.head()
# Out:
# None of the specified columns to drop are present in the DataFrame.
#    playerId                 name  \
# 0   4595348         Malik Nabers
# 1   3043078        Derrick Henry
# 2   4432708  Marvin Harrison Jr.
# 3   4685382      Omarion Hampton
# 4   4683062        Xavier Worthy
#
#                                          reddit_text  \
# 0  Title: Giants' Malik Nabers Taken to Locker Ro...
# 1  Title: 2025 League-Winning Draft Strategies - ...
# 2  Title: Is Marvin Harrison Jr. going to be as a...
# 3  Title: What is the earliest you are willing to...
# 4  Title: Chiefs WR Xavier Worthy, who left yeste...
#
#                                    fantasy_pros_text  \
# 0  Malik Nabers exploded in his rookie season as ...
# 1  The BIG DAWG KEEPS EATING! Some players are ju...
# 2  Marvin Harrison Jr. didn't come close to livin...
# 3  Hampton lands with the Bolts after hearing his...
# 4  Add Xavier Worthy to the list of disappointing...
#
#                                            espn_text  \
# 0  ESPN Fantasy Projection\n\n:\n\nNabers is comi...
# 1  News\n\n:\n\n2 days ago\n\nHenry and other key...
# 2  News\n\n:\n\n2 days ago\n\nHarrison (knee) is ...
# 3  ESPN Fantasy Projection\n\n:\n\nHampton was se...
# 4  News\n\n:\n\n7 days ago\n\nCoach Andy Reid rev...
#
#                                            stats_doc
# 0  PLAYER PROFILE: Malik Nabers (ID: 4595348)\n\n...
# 1  PLAYER PROFILE: Derrick Henry (ID: 3043078)\n\...
# 2  PLAYER PROFILE: Marvin Harrison Jr. (ID: 44327...
# 3  PLAYER PROFILE: Omarion Hampton (ID: 4685382)\...
# 4  PLAYER PROFILE: Xavier Worthy (ID: 4683062)\n\...

# %%
combined_df.to_csv("rag_docs.csv", index=False)

# %%
import getpass
import os

if not os.environ.get("OPENAI_API_KEY"):
  os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter API key for OpenAI: ")

from langchain.chat_models import init_chat_model

llm = init_chat_model("gpt-4o-mini", model_provider="openai")

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_chroma import Chroma

vector_store = Chroma(
    collection_name="example_collection",
    embedding_function=embeddings,
    persist_directory="./chroma_langchain_db",  
)

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
import numpy as np

loader = CSVLoader(file_path="rag_docs.csv")

docs = loader.load()
np.mean([len(doc.page_content) for doc in docs])
# Out:
# np.float64(26202.324675324675)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,  
    chunk_overlap=400,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(docs)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 3957 sub-documents.

# %%
batch_size = 10
for i in range(0, len(all_splits), batch_size):
    batch = all_splits[i:i + batch_size]
    print(f"Adding batch {i//batch_size + 1}/{(len(all_splits) + batch_size - 1)//batch_size}")
    
    try:
        document_ids = vector_store.add_documents(documents=batch)
        print(f"Success: {len(document_ids)} documents added")
    except Exception as e:
        print(f"Error: {e}")
        break
# Out:
# Adding batch 1/396
# ✅ Success: 10 documents added
# Adding batch 2/396
# ✅ Success: 10 documents added
# Adding batch 3/396
# ✅ Success: 10 documents added
# Adding batch 4/396
# ✅ Success: 10 documents added
# Adding batch 5/396
# ✅ Success: 10 documents added
# Adding batch 6/396
# ✅ Success: 10 documents added
# Adding batch 7/396
# ✅ Success: 10 documents added
# Adding batch 8/396
# ✅ Success: 10 documents added
# Adding batch 9/396
# ✅ Success: 10 documents added
# Adding batch 10/396
# ✅ Success: 10 documents added
# Adding batch 11/396
# ✅ Success: 10 documents added
# Adding batch 12/396
# ✅ Success: 10 documents added
# Adding batch 13/396
# ✅ Success: 10 documents added
# Adding batch 14/396
# ✅ Success: 10 documents added
# Adding batch 15/396
# ✅ Success: 10 documents added
# Adding batch 16/396
# ✅ Success: 10 documents added
# Adding batch 17/396
# ✅ Success: 10 documents added
# Adding batch 18/396
# ✅ Success: 10 documents added
# Adding batch 19/396
# ✅ Success: 10 documents added
# Adding batch 20/396
# ✅ Success: 10 documents added
# Adding batch 21/396
# ✅ Success: 10 documents added
# Adding batch 22/396
# ✅ Success: 10 documents added
# Adding batch 23/396
# ✅ Success: 10 documents added
# Adding batch 24/396
# ✅ Success: 10 documents added
# Adding batch 25/396
# ✅ Success: 10 documents added
# Adding batch 26/396
# ✅ Success: 10 documents added
# Adding batch 27/396
# ✅ Success: 10 documents added
# Adding batch 28/396
# ✅ Success: 10 documents added
# Adding batch 29/396
# ✅ Success: 10 documents added
# Adding batch 30/396
# ✅ Success: 10 documents added
# Adding batch 31/396
# ✅ Success: 10 documents added
# Adding batch 32/396
# ✅ Success: 10 documents added
# Adding batch 33/396
# ✅ Success: 10 documents added
# Adding batch 34/396
# ✅ Success: 10 documents added
# Adding batch 35/396
# ✅ Success: 10 documents added
# Adding batch 36/396
# ✅ Success: 10 documents added
# Adding batch 37/396
# ✅ Success: 10 documents added
# Adding batch 38/396
# ✅ Success: 10 documents added
# Adding batch 39/396
# ✅ Success: 10 documents added
# Adding batch 40/396
# ✅ Success: 10 documents added
# Adding batch 41/396
# ✅ Success: 10 documents added
# Adding batch 42/396
# ✅ Success: 10 documents added
# Adding batch 43/396
# ✅ Success: 10 documents added
# Adding batch 44/396
# ✅ Success: 10 documents added
# Adding batch 45/396
# ✅ Success: 10 documents added
# Adding batch 46/396
# ✅ Success: 10 documents added
# Adding batch 47/396
# ✅ Success: 10 documents added
# Adding batch 48/396
# ✅ Success: 10 documents added
# Adding batch 49/396
# ✅ Success: 10 documents added
# Adding batch 50/396
# ✅ Success: 10 documents added
# Adding batch 51/396
# ✅ Success: 10 documents added
# Adding batch 52/396
# ✅ Success: 10 documents added
# Adding batch 53/396
# ✅ Success: 10 documents added
# Adding batch 54/396
# ✅ Success: 10 documents added
# Adding batch 55/396
# ✅ Success: 10 documents added
# Adding batch 56/396
# ✅ Success: 10 documents added
# Adding batch 57/396
# ✅ Success: 10 documents added
# Adding batch 58/396
# ✅ Success: 10 documents added
# Adding batch 59/396
# ✅ Success: 10 documents added
# Adding batch 60/396
# ✅ Success: 10 documents added
# Adding batch 61/396
# ✅ Success: 10 documents added
# Adding batch 62/396
# ✅ Success: 10 documents added
# Adding batch 63/396
# ✅ Success: 10 documents added
# Adding batch 64/396
# ✅ Success: 10 documents added
# Adding batch 65/396
# ✅ Success: 10 documents added
# Adding batch 66/396
# ✅ Success: 10 documents added
# Adding batch 67/396
# ✅ Success: 10 documents added
# Adding batch 68/396
# ✅ Success: 10 documents added
# Adding batch 69/396
# ✅ Success: 10 documents added
# Adding batch 70/396
# ✅ Success: 10 documents added
# Adding batch 71/396
# ✅ Success: 10 documents added
# Adding batch 131/396
# ✅ Success: 10 documents added
# Adding batch 132/396
# ✅ Success: 10 documents added
# Adding batch 133/396
# ✅ Success: 10 documents added
# Adding batch 134/396
# ✅ Success: 10 documents added
# Adding batch 135/396
# ✅ Success: 10 documents added
# Adding batch 136/396
# ✅ Success: 10 documents added
# Adding batch 137/396
# ✅ Success: 10 documents added
# Adding batch 138/396
# ✅ Success: 10 documents added
# Adding batch 139/396
# ✅ Success: 10 documents added
# Adding batch 140/396
# ✅ Success: 10 documents added
# Adding batch 141/396
# ✅ Success: 10 documents added
# Adding batch 142/396
# ✅ Success: 10 documents added
# Adding batch 143/396
# ✅ Success: 10 documents added
# Adding batch 144/396
# ✅ Success: 10 documents added
# Adding batch 145/396
# ✅ Success: 10 documents added
# Adding batch 146/396
# ✅ Success: 10 documents added
# Adding batch 147/396
# ✅ Success: 10 documents added
# Adding batch 148/396
# ✅ Success: 10 documents added
# Adding batch 149/396
# ✅ Success: 10 documents added
# Adding batch 150/396
# ✅ Success: 10 documents added
# Adding batch 151/396
# ✅ Success: 10 documents added
# Adding batch 152/396
# ✅ Success: 10 documents added
# Adding batch 153/396
# ✅ Success: 10 documents added
# Adding batch 154/396
# ✅ Success: 10 documents added
# Adding batch 155/396
# ✅ Success: 10 documents added
# Adding batch 156/396
# ✅ Success: 10 documents added
# Adding batch 157/396
# ✅ Success: 10 documents added
# Adding batch 158/396
# ✅ Success: 10 documents added
# Adding batch 159/396
# ✅ Success: 10 documents added
# Adding batch 160/396
# ✅ Success: 10 documents added
# Adding batch 161/396
# ✅ Success: 10 documents added
# Adding batch 162/396
# ✅ Success: 10 documents added
# Adding batch 163/396
# ✅ Success: 10 documents added
# Adding batch 164/396
# ✅ Success: 10 documents added
# Adding batch 165/396
# ✅ Success: 10 documents added
# Adding batch 166/396
# ✅ Success: 10 documents added
# Adding batch 167/396
# ✅ Success: 10 documents added
# Adding batch 168/396
# ✅ Success: 10 documents added
# Adding batch 169/396
# ✅ Success: 10 documents added
# Adding batch 170/396
# ✅ Success: 10 documents added
# Adding batch 171/396
# ✅ Success: 10 documents added
# Adding batch 172/396
# ✅ Success: 10 documents added
# Adding batch 173/396
# ✅ Success: 10 documents added
# Adding batch 174/396
# ✅ Success: 10 documents added
# Adding batch 175/396
# ✅ Success: 10 documents added
# Adding batch 176/396
# ✅ Success: 10 documents added
# Adding batch 177/396
# ✅ Success: 10 documents added
# Adding batch 178/396
# ✅ Success: 10 documents added
# Adding batch 179/396
# ✅ Success: 10 documents added
# Adding batch 180/396
# ✅ Success: 10 documents added
# Adding batch 181/396
# ✅ Success: 10 documents added
# Adding batch 182/396
# ✅ Success: 10 documents added
# Adding batch 183/396
# ✅ Success: 10 documents added
# Adding batch 184/396
# ✅ Success: 10 documents added
# Adding batch 185/396
# ✅ Success: 10 documents added
# Adding batch 186/396
# ✅ Success: 10 documents added
# Adding batch 187/396
# ✅ Success: 10 documents added
# Adding batch 188/396
# ✅ Success: 10 documents added
# Adding batch 189/396
# ✅ Success: 10 documents added
# Adding batch 190/396
# ✅ Success: 10 documents added
# Adding batch 191/396
# ✅ Success: 10 documents added
# Adding batch 192/396
# ✅ Success: 10 documents added
# Adding batch 193/396
# ✅ Success: 10 documents added
# Adding batch 194/396
# ✅ Success: 10 documents added
# Adding batch 195/396
# ✅ Success: 10 documents added
# Adding batch 196/396
# ✅ Success: 10 documents added
# Adding batch 197/396
# ✅ Success: 10 documents added
# Adding batch 198/396
# ✅ Success: 10 documents added
# Adding batch 199/396
# ✅ Success: 10 documents added
# Adding batch 200/396
# ✅ Success: 10 documents added
# Adding batch 201/396
# ✅ Success: 10 documents added
# Adding batch 202/396
# ✅ Success: 10 documents added
# Adding batch 203/396
# ✅ Success: 10 documents added
# Adding batch 204/396
# ✅ Success: 10 documents added
# Adding batch 205/396
# ✅ Success: 10 documents added
# Adding batch 206/396
# ✅ Success: 10 documents added
# Adding batch 207/396
# ✅ Success: 10 documents added
# Adding batch 208/396
# ✅ Success: 10 documents added
# Adding batch 209/396
# ✅ Success: 10 documents added
# Adding batch 210/396
# ✅ Success: 10 documents added
# Adding batch 211/396
# ✅ Success: 10 documents added
# Adding batch 212/396
# ✅ Success: 10 documents added
# Adding batch 213/396
# ✅ Success: 10 documents added
# Adding batch 214/396
# ✅ Success: 10 documents added
# Adding batch 215/396
# ✅ Success: 10 documents added
# Adding batch 216/396
# ✅ Success: 10 documents added
# Adding batch 217/396
# ✅ Success: 10 documents added
# Adding batch 218/396
# ✅ Success: 10 documents added
# Adding batch 219/396
# ✅ Success: 10 documents added
# Adding batch 220/396
# ✅ Success: 10 documents added
# Adding batch 221/396
# ✅ Success: 10 documents added
# Adding batch 222/396
# ✅ Success: 10 documents added
# Adding batch 223/396
# ✅ Success: 10 documents added
# Adding batch 224/396
# ✅ Success: 10 documents added
# Adding batch 225/396
# ✅ Success: 10 documents added
# Adding batch 226/396
# ✅ Success: 10 documents added
# Adding batch 227/396
# ✅ Success: 10 documents added
# Adding batch 228/396
# ✅ Success: 10 documents added
# Adding batch 229/396
# ✅ Success: 10 documents added
# Adding batch 230/396
# ✅ Success: 10 documents added
# Adding batch 231/396
# ✅ Success: 10 documents added
# Adding batch 232/396
# ✅ Success: 10 documents added
# Adding batch 233/396
# ✅ Success: 10 documents added
# Adding batch 234/396
# ✅ Success: 10 documents added
# Adding batch 235/396
# ✅ Success: 10 documents added
# Adding batch 236/396
# ✅ Success: 10 documents added
# Adding batch 237/396
# ✅ Success: 10 documents added
# Adding batch 238/396
# ✅ Success: 10 documents added
# Adding batch 239/396
# ✅ Success: 10 documents added
# Adding batch 240/396
# ✅ Success: 10 documents added
# Adding batch 241/396
# ✅ Success: 10 documents added
# Adding batch 242/396
# ✅ Success: 10 documents added
# Adding batch 243/396
# ✅ Success: 10 documents added
# Adding batch 244/396
# ✅ Success: 10 documents added
# Adding batch 245/396
# ✅ Success: 10 documents added
# Adding batch 246/396
# ✅ Success: 10 documents added
# Adding batch 247/396
# ✅ Success: 10 documents added
# Adding batch 248/396
# ✅ Success: 10 documents added
# Adding batch 249/396
# ✅ Success: 10 documents added
# Adding batch 250/396
# ✅ Success: 10 documents added
# Adding batch 251/396
# ✅ Success: 10 documents added
# Adding batch 252/396
# ✅ Success: 10 documents added
# Adding batch 253/396
# ✅ Success: 10 documents added
# Adding batch 254/396
# ✅ Success: 10 documents added
# Adding batch 255/396
# ✅ Success: 10 documents added
# Adding batch 256/396
# ✅ Success: 10 documents added
# Adding batch 257/396
# ✅ Success: 10 documents added
# Adding batch 258/396
# ✅ Success: 10 documents added
# Adding batch 259/396
# ✅ Success: 10 documents added
# Adding batch 260/396
# ✅ Success: 10 documents added
# Adding batch 261/396
# ✅ Success: 10 documents added
# Adding batch 262/396
# ✅ Success: 10 documents added
# Adding batch 263/396
# ✅ Success: 10 documents added
# Adding batch 264/396
# ✅ Success: 10 documents added
# Adding batch 265/396
# ✅ Success: 10 documents added
# Adding batch 266/396
# ✅ Success: 10 documents added
# Adding batch 267/396
# ✅ Success: 10 documents added
# Adding batch 268/396
# ✅ Success: 10 documents added
# Adding batch 269/396
# ✅ Success: 10 documents added
# Adding batch 270/396
# ✅ Success: 10 documents added
# Adding batch 271/396
# ✅ Success: 10 documents added
# Adding batch 272/396
# ✅ Success: 10 documents added
# Adding batch 273/396
# ✅ Success: 10 documents added
# Adding batch 274/396
# ✅ Success: 10 documents added
# Adding batch 275/396
# ✅ Success: 10 documents added
# Adding batch 276/396
# ✅ Success: 10 documents added
# Adding batch 277/396
# ✅ Success: 10 documents added
# Adding batch 278/396
# ✅ Success: 10 documents added
# Adding batch 279/396
# ✅ Success: 10 documents added
# Adding batch 280/396
# ✅ Success: 10 documents added
# Adding batch 281/396
# ✅ Success: 10 documents added
# Adding batch 282/396
# ✅ Success: 10 documents added
# Adding batch 283/396
# ✅ Success: 10 documents added
# Adding batch 284/396
# ✅ Success: 10 documents added
# Adding batch 285/396
# ✅ Success: 10 documents added
# Adding batch 286/396
# ✅ Success: 10 documents added
# Adding batch 287/396
# ✅ Success: 10 documents added
# Adding batch 288/396
# ✅ Success: 10 documents added
# Adding batch 289/396
# ✅ Success: 10 documents added
# Adding batch 290/396
# ✅ Success: 10 documents added
# Adding batch 291/396
# ✅ Success: 10 documents added
# Adding batch 292/396
# ✅ Success: 10 documents added
# Adding batch 293/396
# ✅ Success: 10 documents added
# Adding batch 294/396
# ✅ Success: 10 documents added
# Adding batch 295/396
# ✅ Success: 10 documents added
# Adding batch 296/396
# ✅ Success: 10 documents added
# Adding batch 297/396
# ✅ Success: 10 documents added
# Adding batch 298/396
# ✅ Success: 10 documents added
# Adding batch 299/396
# ✅ Success: 10 documents added
# Adding batch 300/396
# ✅ Success: 10 documents added
# Adding batch 301/396
# ✅ Success: 10 documents added
# Adding batch 302/396
# ✅ Success: 10 documents added
# Adding batch 303/396
# ✅ Success: 10 documents added
# Adding batch 304/396
# ✅ Success: 10 documents added
# Adding batch 305/396
# ✅ Success: 10 documents added
# Adding batch 306/396
# ✅ Success: 10 documents added
# Adding batch 366/396
# ✅ Success: 10 documents added
# Adding batch 367/396
# ✅ Success: 10 documents added
# Adding batch 368/396
# ✅ Success: 10 documents added
# Adding batch 369/396
# ✅ Success: 10 documents added
# Adding batch 370/396
# ✅ Success: 10 documents added
# Adding batch 371/396
# ✅ Success: 10 documents added
# Adding batch 372/396
# ✅ Success: 10 documents added
# Adding batch 373/396
# ✅ Success: 10 documents added
# Adding batch 374/396
# ✅ Success: 10 documents added
# Adding batch 375/396
# ✅ Success: 10 documents added
# Adding batch 376/396
# ✅ Success: 10 documents added
# Adding batch 377/396
# ✅ Success: 10 documents added
# Adding batch 378/396
# ✅ Success: 10 documents added
# Adding batch 379/396
# ✅ Success: 10 documents added
# Adding batch 380/396
# ✅ Success: 10 documents added
# Adding batch 381/396
# ✅ Success: 10 documents added
# Adding batch 382/396
# ✅ Success: 10 documents added
# Adding batch 383/396
# ✅ Success: 10 documents added
# Adding batch 384/396
# ✅ Success: 10 documents added
# Adding batch 385/396
# ✅ Success: 10 documents added
# Adding batch 386/396
# ✅ Success: 10 documents added
# Adding batch 387/396
# ✅ Success: 10 documents added
# Adding batch 388/396
# ✅ Success: 10 documents added
# Adding batch 389/396
# ✅ Success: 10 documents added
# Adding batch 390/396
# ✅ Success: 10 documents added
# Adding batch 391/396
# ✅ Success: 10 documents added
# Adding batch 392/396
# ✅ Success: 10 documents added
# Adding batch 393/396
# ✅ Success: 10 documents added
# Adding batch 394/396
# ✅ Success: 10 documents added
# Adding batch 395/396
# ✅ Success: 10 documents added
# Adding batch 396/396
# ✅ Success: 7 documents added

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("""
You are an expert fantasy football advisor with deep knowledge of player performance, injuries, matchups, and league trends.

Use the following player information to provide helpful fantasy football advice. Be specific about why you recommend or don't recommend a player.

IMPORTANT GUIDELINES:
- ONLY reference these specific stats in your recommendations: Total Points, Average Points Per Game, Projected Season Total, Projected Weekly Average, League Ownership %, Start Rate %
- Use all other information (injury status, team, position, expert analysis, etc.) as CONTEXT to inform your advice, but do not quote specific numbers from those areas
- Focus on the measurable fantasy performance data listed above for concrete recommendations

PLAYER CONTEXT:
{context}

QUESTION: {question}

FANTASY ADVICE:
- Give clear start/sit recommendations when relevant
- Base recommendations primarily on the allowed stats: points, projections, and ownership rates
- Explain your reasoning using the provided performance data
- Use injury status, expert opinions, and other context to support your analysis (without citing specific details)
- If you don't have enough statistical information, say so clearly
- Keep advice practical and actionable

Answer:
""")

# %%
from langchain_core.documents import Document
from typing_extensions import List, TypedDict


class State(TypedDict):
    question: str
    context: List[Document]
    answer: str

# %%
def retrieve(state: State):
    retrieved_docs = vector_store.similarity_search(state["question"])
    return {"context": retrieved_docs}


def generate(state: State):
    docs_content = "\n\n".join(doc.page_content for doc in state["context"])
    messages = prompt.invoke({"question": state["question"], "context": docs_content})
    response = llm.invoke(messages)
    return {"answer": response.content}

# %%
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %%
result = graph.invoke({"question": "Who are some sleepers to watch out for this year?"})

print(f"Context: {result['context']}\n\n")
print(f"Answer: {result['answer']}")
# Out:
# Context: [Document(id='b8d69953-b254-46a7-907e-f2f31a51ccd6', metadata={'start_index': 11160, 'row': 177, 'source': 'rag_docs.csv'}, page_content='Absolute beast. Only question is can the o line hold up for stroud\n---\nTitle: Who are your sleepers and why?\nPost: Mine are as follows:\n\n1. Jayden Higgins (WR – Houston Texans)\n\t•\tBig-bodied playmaker (6’4″, 215 lbs) with rare size-speed combo; ran a 4.47-second 40-yard dash at the combine.\n\t•\tPosted 1,183 receiving yards and 9 scores at Iowa State; excels in contested catches and deep routes￼.\n\t•\tWith Tank Dell’s knee uncertain and Nico Collins likely drawing doubles, Higgins could carve out WR3/slot role early and climb depth chart.\n\n2. Tucker Kraft (TE – Green Bay Packers)\n\t•\tPosted a TE10 finish in PPR in 2024 with 50 catches, 707 yards & 7 TDs while stepping in as TE1 during injuries to Luke Musgrave .\n\t•\tPackers coach Matt LaFleur praised him post‑playoffs, signaling expanded usage in 2025￼.\n\t•\tADP late in drafts (e.g. Underdog pick ~119), offering great value behind volume/starved WR corps.\n\n3. Marvin Mims Jr. (WR – Denver Broncos)\n\t•\tThird-year breakouts are common; Mims posted a late surge in 2024 (52 fantasy points and 4 TDs last two weeks).\n\t•\tLed all WRs in yards per route run post–Week 11 (3.63), showing burgeoning efficiency￼.\n\t•\tWith Bo Nix set for year two under coaching continuity, and no dominant WR1 outside Courtland Sutton, Mims is well‑positioned for bounce-back success￼.\n\n4. KaVontae Turpin (WR – Dallas Cowboys)\n\t•\tDynamic return and gadget player transitioning into offense during 2025 camp under OC Brian Schottenheimer.\n\t•\tLogged 31 receptions for 420 yards and 2 TDs in limited usage; showed ability both receiving and as a rusher ￼.\n\t•\tWith defenses focused on Lamb and Pickens, Turpin could exploit mismatches and become a PPR-friendly flex option. Training camp buzz indicates elevated role.'), Document(id='0170f842-3b30-4075-9667-54e3013d56b9', metadata={'source': 'rag_docs.csv', 'start_index': 0, 'row': 55}, page_content='playerId: 4385690\nname: Dalton Kincaid\nreddit_text: Title: Who are your sleepers and why?\nPost: Mine are as follows:\n\n1. Jayden Higgins (WR – Houston Texans)\n\t•\tBig-bodied playmaker (6’4″, 215 lbs) with rare size-speed combo; ran a 4.47-second 40-yard dash at the combine.\n\t•\tPosted 1,183 receiving yards and 9 scores at Iowa State; excels in contested catches and deep routes￼.\n\t•\tWith Tank Dell’s knee uncertain and Nico Collins likely drawing doubles, Higgins could carve out WR3/slot role early and climb depth chart.\n\n2. Tucker Kraft (TE – Green Bay Packers)\n\t•\tPosted a TE10 finish in PPR in 2024 with 50 catches, 707 yards & 7 TDs while stepping in as TE1 during injuries to Luke Musgrave .\n\t•\tPackers coach Matt LaFleur praised him post‑playoffs, signaling expanded usage in 2025￼.\n\t•\tADP late in drafts (e.g. Underd